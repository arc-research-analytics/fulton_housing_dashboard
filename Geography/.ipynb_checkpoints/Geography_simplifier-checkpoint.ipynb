# %%
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas

# %%
# read in Super district ('SD') geography
SD_url = "https://services1.arcgis.com/Ug5xGQbHsD8zuZzM/arcgis/rest/services/ACS_2021_Population/FeatureServer/20/query?where=PlanningRegion%20%3D%20'ATLANTA%20REGIONAL%20COMMISSION'&outFields=GEOID,NAME&outSR=4326&f=json"
SD_gdf = gpd.read_file(SD_url)

# gdf1 = gpd.read_file('../Geography/Fulton_CTs_GEOID.gpkg')

# # simplify, apply to geometry column
# tolerance = 0.005
# gdf1['simplified_geometry'] = gdf1['geometry'].apply(lambda geom: geom.simplify(tolerance))

# gdf1 = gdf1[['Sub-geo', 'GEOID', 'simplified_geometry']]
# gdf1.rename(columns={'simplified_geometry':'geometry'}, inplace=True)
# gdf1.set_geometry("geometry", inplace=True)

# gdf1.to_file('../Geography/.gpkg')
SD_gdf
# Out:
#     GEOID             NAME                                           geometry
# 0   SD021          Airport  POLYGON ((-84.45095 33.64122, -84.45094 33.641...
# 1   SD045   Atlanta-DeKalb  POLYGON ((-84.34725 33.78306, -84.34725 33.783...
# 2   SD004         Buckhead  POLYGON ((-84.34822 33.88884, -84.34817 33.887...
# 3   SD008      CBD Atlanta  POLYGON ((-84.39341 33.77132, -84.39291 33.771...
# 4   SD072    Cent Gwinnett  POLYGON ((-84.12053 34.03348, -84.12047 34.033...
# 5   SD041         Chamblee  POLYGON ((-84.33273 33.96948, -84.33202 33.969...
# 6   SD035       Cumberland  POLYGON ((-84.46658 33.95251, -84.46544 33.952...
# 7   SD142          Cumming  POLYGON ((-84.24471 34.29680, -84.24476 34.296...
# 8   SD046          Decatur  POLYGON ((-84.29579 33.79268, -84.29564 33.792...
# 9   SD017  E Cent Cherokee  POLYGON ((-84.30027 34.31653, -84.29973 34.316...
# 10  SD052        E Douglas  POLYGON ((-84.71626 33.80626, -84.71597 33.806...
# ...
